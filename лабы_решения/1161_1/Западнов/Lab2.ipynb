# %%
import pandas as pd
import numpy as np
df = pd.read_csv('../../../data/titanic_train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)
print(df.shape)
# Out:
# (891, 12)

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB
# None

# %%
df['Pclass'] = df['Pclass'].astype('float64')
df.sort_values(by='Fare', ascending=False).head()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1     1.0                    Ward, Miss. Anna
# 737          738         1     1.0              Lesurer, Mr. Gustave J
# 679          680         1     1.0  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1     1.0          Fortune, Miss. Mabel Helen
# 27            28         0     1.0      Fortune, Mr. Charles Alexander
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 88   female  23.0      3      2     19950  263.0000  C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S

# %%
df.sort_values(by=['Age','Fare'], ascending=[True,False]).head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1     3.0  Thomas, Master. Assad Alexander    male
# 755          756         1     2.0        Hamalainen, Master. Viljo    male
# 469          470         1     3.0    Baclini, Miss. Helene Barbara  female
# 644          645         1     3.0           Baclini, Miss. Eugenie  female
# 78            79         1     2.0    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 469  0.75      2      1    2666  19.2583   NaN        C
# 644  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
df=df.astype(str)
df.apply(np.max)
# Out:
# PassengerId                             99
# Survived                                 1
# Pclass                                 3.0
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                    nan
# SibSp                                    8
# Parch                                    6
# Ticket                           WE/P 5735
# Fare                                  93.5
# Cabin                                  nan
# Embarked                               nan
# dtype: object

# %%
df = pd.read_csv('../../../data/titanic_train.csv')
d = { 'male' : True ,  'female' : False }
df['Sex']=df['Sex'].map(d)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name    Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris   True  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  False  38.0      1
# 2                             Heikkinen, Miss. Laina  False  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  False  35.0      1
# 4                           Allen, Mr. William Henry   True  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import warnings 
warnings.simplefilter('ignore')

# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

from pylab import rcParams
rcParams['figure.figsize'] = 8, 5
df= pd.read_csv('../../../data/titanic_train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df = df.dropna() # убираем записи с пропусками
print(df.shape)
# Out:
# (183, 12)

# %%
useful_cols = ['Name','Survived', 'Sex', 'Age' ]
df[useful_cols].head()
# Out:
#                                                  Name  Survived     Sex   Age
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...         1  female  38.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)         1  female  35.0
# 6                             McCarthy, Mr. Timothy J         0    male  54.0
# 10                    Sandstrom, Miss. Marguerite Rut         1  female   4.0
# 11                           Bonnell, Miss. Elizabeth         1  female  58.0

# %%
sns_plot = sns.pairplot(df[useful_cols])
sns_plot.savefig('pairplot.png')

# %%
sns.distplot(df.Age)

# %%
survived_sex_age = df.pivot_table ( index = 'Age', columns = 'Sex', values='Survived', aggfunc=sum).fillna(0).applymap(float)
sns.heatmap(survived_sex_age, annot=True, fmt=".1f", linewidth=.10)

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df.plot(kind="bar", rot=0)
