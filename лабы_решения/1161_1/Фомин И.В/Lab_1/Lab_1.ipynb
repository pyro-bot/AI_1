# %%
print(2+3)
print(4*5)
print(5-1)
print(40/2)
print(2**5)

print("Qwe")
print("Hi there "+"Qwe")
print("Three"*3)
print("Runnin' down the hill")
print('Runnin\' down the hill')
print("Qwe".upper())
print(len("QWE"))

#print(len(123232))
print(len(str(24233)))
#print(int("hello"))

name="Qwe"
print(name)
name="Qwe1"
print(name)
print(len(name))
a=4
b=6
print(a*b)

city="Tokyo"
print(city)
#print(ctiy)

lottery=[1, 443, 44, 434, 4545, 343]
print(len(lottery))
print(lottery)
lottery.sort()
print(lottery)
lottery.reverse()
print(lottery)
lottery.append(732)
print(lottery)
print(lottery[0])
print(lottery[1])
lottery.pop(0)
print(lottery)

participant={'name':"Qwe", 'country':'Poland', 'favorite_numbers':[23, 232, 23]}
print(participant)
print(participant['name'])
participant['favorite_language']='Python'
print(len(participant))
participant.pop('favorite_numbers')
print(participant)
participant['favorite_language']='Assembler'
print(participant)


print(5>3)
print(3<1)
print(5>2*2)
print(1==1)
print(5!=2)
print(6>=12/2)
print(3<=2)
print(6>2 and 2<3)
print(6>2 or 2<3)
#print(6 >"rrgrg")

a=True
print(a)
a=2>5
print(a)

name="Qwe"
if name=="Qwe1":
    print("Hey Qwe1")
elif name=="Qwe":
    print("Hey Qwe")
else:
    print("Hey anonymous")
    
def hi():
    print("hi there")
    print("How are you?")
hi()

def hi(name):
    if (name=="Qwe1"):
        print("Hey Qwe1")
    elif(name=="Qwe"):
        print("Hey Qwe")
    else:
        print("Hey anonymous")
hi("Qwe")

def hi(name):
    print("Hi "+name+'!')
    
girls=["Rachel", 'Monica', 'Qwe']
for name in girls:
        hi(name)
        print("Next girl")
for i in range(1,6):
       print(i)
        
print("""hhuugugguguuhuihuhihkuhuuih
ukhuguyjghgyvgyhvuvuvhjhgy
ugyugygygyhgjhygyggfgyuygvyhvyuvkhukih""")
# Out:
# 5
# 20
# 4
# 20.0
# 32
# Qwe
# Hi there Qwe
# ThreeThreeThree
# Runnin' down the hill
# Runnin' down the hill
# QWE
# 3
# 5
# Qwe
# Qwe1
# 4
# 24
# Tokyo
# 6
# [1, 443, 44, 434, 4545, 343]
# [1, 44, 343, 434, 443, 4545]
# [4545, 443, 434, 343, 44, 1]
# [4545, 443, 434, 343, 44, 1, 732]
# 4545
# 443
# [443, 434, 343, 44, 1, 732]
# {'name': 'Qwe', 'country': 'Poland', 'favorite_numbers': [23, 232, 23]}
# Qwe
# 4
# {'name': 'Qwe', 'country': 'Poland', 'favorite_language': 'Python'}
# {'name': 'Qwe', 'country': 'Poland', 'favorite_language': 'Assembler'}
# True
# False
# True
# True
# True
# True
# False
# True
# True
# True
# False
# Hey Qwe
# hi there
# How are you?
# Hey Qwe
# Hi Rachel!
# Next girl
# Hi Monica!
# Next girl
# Hi Qwe!
# Next girl
# 1
# 2
# 3
# 4
# 5
# hhuugugguguuhuihuhihkuhuuih
# ukhuguyjghgyvgyhvuvuvhjhgy
# ugyugygygyhgjhygyggfgyuygvyhvyuvkhukih
